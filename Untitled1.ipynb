# %%
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
# %matplotlib inline

# Site to use: https://www.dnd-spells.com/spells
# spell site syntax: https://www.dnd-spells.com/spell/zone-of-truth

# GET ALL THE SPELL SITES TO SCRAP
#define site to use
url = 'https://www.dnd-spells.com/spells'
#get content of main page
resp = requests.get(url)
#put this into beautiful soup format
soup = BeautifulSoup(resp.text)
#get just the content of the spells
info = soup.table
#pull all the links from the spell table
spells = info.find_all('a')
#make a list of all the unique links from spells (they're listed twice because of 'open in new window')
spell_links = []
for item in spells:
    link = item.get('href')
    if link not in spell_links:
        spell_links.append(link)
# Out:
# //anaconda/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file //anaconda/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
title = []
school = []
level = []
casting_time = []
spell_range = []
components = []
duration = []
description = []
source = []
spell_classes = []
higher_class = []

attributes = [title,school,level,casting_time,spell_range,components,duration,description,source,spell_classes,higher_class]


# ITERATE THROUGH THE PAGES GETTING INFORMATION
for link in spell_links:
    print link
    try:
        content = requests.get(link)
        spell_info =  BeautifulSoup(content.text)

        head = spell_info.find_all('h1')
        for item in head:
            title.append(item.find('span').find(text=True))

        body = spell_info.findAll('p')

        school.append(body[1].find(text=True))

        fine_details = body[2].find_all('strong')
        level.append(fine_details[0].find(text=True))
        casting_time.append(fine_details[1].find(text=True))
        spell_range.append(fine_details[2].find(text=True))
        components.append(fine_details[3].find(text=True).split(', '))
        duration.append(fine_details[4].find(text=True))

        description.append(body[3])

        if 'Page' in body[4].find(text=True):
            # source.append(re.findall(r'[^\n\s].*[^(\s{3,})]', body[4].find(text=True))[0])
            sourcenum = 4
            classesnum = 5
            higher_class.append('n/a')
        else:
            sourcenum = 5
            classesnum = 6
            higher_class.append(body[4])

        source.append(re.findall(r'[^\n\s].*[^(\s{3,})]', body[sourcenum].find(text=True))[0])

        messyclasses = body[classesnum].find_all('a')
        classes = []
        for item in messyclasses:
            classes.append(re.findall(r'[^/]*?$', item.get('href'))[0])
        spell_classes.append(classes)
    except:
        print 'error'

#CREATE DATAFRAME
index = ['title','school','level','casting_time','spell_range','components','duration','description','source','spell_classes','higher_class']
spells_df = pd.DataFrame(attributes, index=index)

spells_df

spells_df.rename(index={'spell_range':'range'}, inplace=True)

spells_df.to_csv('spells.csv', encoding='utf-8')

spellsforjson = pd.read_csv('spells.csv')
spellsforjson.set_index('Unnamed: 0', inplace=True)
spellsforjson.columns = spellsforjson.loc['title']
spellsforjson.drop('title',axis=0,inplace=True)

spellsforjson
spellsforjson.to_json('spells.json')
# Out:
# https://www.dnd-spells.com/spell/acid-splash
# https://www.dnd-spells.com/spell/aid
# https://www.dnd-spells.com/spell/alarm-ritual
# https://www.dnd-spells.com/spell/alter-self
# https://www.dnd-spells.com/spell/animal-friendship
# https://www.dnd-spells.com/spell/animal-messenger-ritual
# https://www.dnd-spells.com/spell/animal-shapes
# https://www.dnd-spells.com/spell/animate-dead
# https://www.dnd-spells.com/spell/animate-objects
# https://www.dnd-spells.com/spell/antilife-shell
# https://www.dnd-spells.com/spell/antimagic-field
# https://www.dnd-spells.com/spell/antipathysympathy
# https://www.dnd-spells.com/spell/arcane-eye
# https://www.dnd-spells.com/spell/arcane-gate
# https://www.dnd-spells.com/spell/arcane-lock
# https://www.dnd-spells.com/spell/armor-of-agathys
# https://www.dnd-spells.com/spell/arms-of-hadar
# https://www.dnd-spells.com/spell/astral-projection
# https://www.dnd-spells.com/spell/augury-ritual
# https://www.dnd-spells.com/spell/aura-of-life
# https://www.dnd-spells.com/spell/aura-of-purity
# https://www.dnd-spells.com/spell/aura-of-vitality
# https://www.dnd-spells.com/spell/awaken
# https://www.dnd-spells.com/spell/bane
# https://www.dnd-spells.com/spell/banishing-smite
# https://www.dnd-spells.com/spell/banishment
# https://www.dnd-spells.com/spell/barkskin
# https://www.dnd-spells.com/spell/beacon-of-hope
# https://www.dnd-spells.com/spell/beast-sense-ritual
# https://www.dnd-spells.com/spell/bestow-curse
# https://www.dnd-spells.com/spell/bigbys-hand
# https://www.dnd-spells.com/spell/blade-barrier
# https://www.dnd-spells.com/spell/blade-ward
# https://www.dnd-spells.com/spell/bless
# https://www.dnd-spells.com/spell/blight
# https://www.dnd-spells.com/spell/blinding-smite
# https://www.dnd-spells.com/spell/blindnessdeafness
# https://www.dnd-spells.com/spell/blink
# https://www.dnd-spells.com/spell/blur
# https://www.dnd-spells.com/spell/branding-smite
# https://www.dnd-spells.com/spell/burning-hands
# https://www.dnd-spells.com/spell/call-lightning
# https://www.dnd-spells.com/spell/calm-emotions
# https://www.dnd-spells.com/spell/chain-lightning
# https://www.dnd-spells.com/spell/charm-person
# https://www.dnd-spells.com/spell/chill-touch
# https://www.dnd-spells.com/spell/chromatic-orb
# https://www.dnd-spells.com/spell/circle-of-death
# https://www.dnd-spells.com/spell/circle-of-power
# https://www.dnd-spells.com/spell/clairvoyance
# https://www.dnd-spells.com/spell/clone
# https://www.dnd-spells.com/spell/cloud-of-daggers
# https://www.dnd-spells.com/spell/cloudkill
# https://www.dnd-spells.com/spell/color-spray
# https://www.dnd-spells.com/spell/command
# https://www.dnd-spells.com/spell/commune-ritual
# https://www.dnd-spells.com/spell/commune-with-nature-ritual
# https://www.dnd-spells.com/spell/compelled-duel
# https://www.dnd-spells.com/spell/comprehend-languages-ritual
# https://www.dnd-spells.com/spell/compulsion
# https://www.dnd-spells.com/spell/cone-of-cold
# https://www.dnd-spells.com/spell/confusion
# https://www.dnd-spells.com/spell/conjure-animals
# https://www.dnd-spells.com/spell/conjure-barrage
# https://www.dnd-spells.com/spell/conjure-celestial
# https://www.dnd-spells.com/spell/conjure-elemental
# https://www.dnd-spells.com/spell/conjure-fey
# https://www.dnd-spells.com/spell/conjure-minor-elementals
# https://www.dnd-spells.com/spell/conjure-volley
# https://www.dnd-spells.com/spell/conjure-woodland-beings
# https://www.dnd-spells.com/spell/contact-other-plane-ritual
# https://www.dnd-spells.com/spell/contagion
# https://www.dnd-spells.com/spell/contingency
# https://www.dnd-spells.com/spell/continual-flame
# https://www.dnd-spells.com/spell/control-water
# https://www.dnd-spells.com/spell/control-weather
# https://www.dnd-spells.com/spell/cordon-of-arrows
# https://www.dnd-spells.com/spell/counterspell
# https://www.dnd-spells.com/spell/create-food-and-water
# https://www.dnd-spells.com/spell/create-or-destroy-water
# https://www.dnd-spells.com/spell/create-undead
# https://www.dnd-spells.com/spell/creation
# https://www.dnd-spells.com/spell/crown-of-madness
# https://www.dnd-spells.com/spell/crusaders-mantle
# https://www.dnd-spells.com/spell/cure-wounds
# https://www.dnd-spells.com/spell/dancing-lights
# https://www.dnd-spells.com/spell/darkness
# https://www.dnd-spells.com/spell/darkvision
# https://www.dnd-spells.com/spell/daylight
# https://www.dnd-spells.com/spell/death-ward
# https://www.dnd-spells.com/spell/delayed-blast-fireball
# https://www.dnd-spells.com/spell/demiplane
# https://www.dnd-spells.com/spell/destructive-wave
# https://www.dnd-spells.com/spell/detect-evil-and-good
# https://www.dnd-spells.com/spell/detect-magic-ritual
# https://www.dnd-spells.com/spell/detect-poison-and-disease
# https://www.dnd-spells.com/spell/detect-thoughts
# https://www.dnd-spells.com/spell/dimension-door
# https://www.dnd-spells.com/spell/disguise-self
# https://www.dnd-spells.com/spell/disintegrate
# https://www.dnd-spells.com/spell/dispel-evil-and-good
# https://www.dnd-spells.com/spell/dispel-magic
# https://www.dnd-spells.com/spell/dissonant-whispers
# https://www.dnd-spells.com/spell/divination-ritual
# https://www.dnd-spells.com/spell/divine-favor
# https://www.dnd-spells.com/spell/divine-word
# https://www.dnd-spells.com/spell/dominate-beast
# https://www.dnd-spells.com/spell/dominate-monster
# https://www.dnd-spells.com/spell/dominate-person
# https://www.dnd-spells.com/spell/drawmijs-instant-summons-ritual
# https://www.dnd-spells.com/spell/dream
# https://www.dnd-spells.com/spell/druidcraft
# https://www.dnd-spells.com/spell/earthquake
# https://www.dnd-spells.com/spell/eldritch-blast
# https://www.dnd-spells.com/spell/elemental-weapon
# https://www.dnd-spells.com/spell/enhance-ability
# https://www.dnd-spells.com/spell/enlargereduce
# https://www.dnd-spells.com/spell/ensnaring-strike
# https://www.dnd-spells.com/spell/entangle
# https://www.dnd-spells.com/spell/enthrall
# https://www.dnd-spells.com/spell/etherealness
# https://www.dnd-spells.com/spell/evards-black-tentacles
# https://www.dnd-spells.com/spell/expeditious-retreat
# https://www.dnd-spells.com/spell/eyebite
# https://www.dnd-spells.com/spell/fabricate
# https://www.dnd-spells.com/spell/faerie-fire
# https://www.dnd-spells.com/spell/false-life
# https://www.dnd-spells.com/spell/fear
# https://www.dnd-spells.com/spell/feather-fall
# https://www.dnd-spells.com/spell/feeblemind
# https://www.dnd-spells.com/spell/feign-death-ritual
# https://www.dnd-spells.com/spell/find-familiar-ritual
# https://www.dnd-spells.com/spell/find-steed
# https://www.dnd-spells.com/spell/find-the-path
# https://www.dnd-spells.com/spell/find-traps
# https://www.dnd-spells.com/spell/finger-of-death
# https://www.dnd-spells.com/spell/fire-bolt
# https://www.dnd-spells.com/spell/fire-shield
# https://www.dnd-spells.com/spell/fire-storm
# https://www.dnd-spells.com/spell/fireball
# https://www.dnd-spells.com/spell/flame-blade
# https://www.dnd-spells.com/spell/flame-strike
# https://www.dnd-spells.com/spell/flaming-sphere
# https://www.dnd-spells.com/spell/flesh-to-stone
# https://www.dnd-spells.com/spell/fly
# https://www.dnd-spells.com/spell/fog-cloud
# https://www.dnd-spells.com/spell/forbiddance-ritual
# https://www.dnd-spells.com/spell/forcecage
# https://www.dnd-spells.com/spell/foresight
# https://www.dnd-spells.com/spell/freedom-of-movement
# https://www.dnd-spells.com/spell/friends
# https://www.dnd-spells.com/spell/gaseous-form
# https://www.dnd-spells.com/spell/gate
# https://www.dnd-spells.com/spell/geas
# https://www.dnd-spells.com/spell/gentle-repose-ritual
# https://www.dnd-spells.com/spell/giant-insect
# https://www.dnd-spells.com/spell/glibness
# https://www.dnd-spells.com/spell/globe-of-invulnerability
# https://www.dnd-spells.com/spell/glyph-of-warding
# error
# https://www.dnd-spells.com/spell/goodberry
# https://www.dnd-spells.com/spell/grasping-vine
# https://www.dnd-spells.com/spell/grease
# https://www.dnd-spells.com/spell/greater-invisibility
# https://www.dnd-spells.com/spell/greater-restoration
# https://www.dnd-spells.com/spell/guardian-of-faith
# https://www.dnd-spells.com/spell/guards-and-wards
# https://www.dnd-spells.com/spell/guidance
# https://www.dnd-spells.com/spell/guiding-bolt
# https://www.dnd-spells.com/spell/gust-of-wind
# https://www.dnd-spells.com/spell/hail-of-thorns
# https://www.dnd-spells.com/spell/hallow
# https://www.dnd-spells.com/spell/hallucinatory-terrain
# https://www.dnd-spells.com/spell/harm
# https://www.dnd-spells.com/spell/haste
# https://www.dnd-spells.com/spell/heal
# https://www.dnd-spells.com/spell/healing-word
# https://www.dnd-spells.com/spell/heat-metal
# https://www.dnd-spells.com/spell/hellish-rebuke
# https://www.dnd-spells.com/spell/heroes-feast
# https://www.dnd-spells.com/spell/heroism
# https://www.dnd-spells.com/spell/hex
# https://www.dnd-spells.com/spell/hold-monster
# https://www.dnd-spells.com/spell/hold-person
# https://www.dnd-spells.com/spell/holy-aura
# https://www.dnd-spells.com/spell/hunger-of-hadar
# https://www.dnd-spells.com/spell/hunters-mark
# https://www.dnd-spells.com/spell/hypnotic-pattern
# https://www.dnd-spells.com/spell/ice-storm
# https://www.dnd-spells.com/spell/identify-ritual
# https://www.dnd-spells.com/spell/illusory-script-ritual
# https://www.dnd-spells.com/spell/imprisonment
# https://www.dnd-spells.com/spell/incendiary-cloud
# https://www.dnd-spells.com/spell/inflict-wounds
# https://www.dnd-spells.com/spell/insect-plague
# https://www.dnd-spells.com/spell/invisibility
# https://www.dnd-spells.com/spell/jump
# https://www.dnd-spells.com/spell/knock
# https://www.dnd-spells.com/spell/legend-lore
# https://www.dnd-spells.com/spell/leomunds-secret-chest
# https://www.dnd-spells.com/spell/leomunds-tiny-hut-ritual
# https://www.dnd-spells.com/spell/lesser-restoration
# https://www.dnd-spells.com/spell/levitate
# https://www.dnd-spells.com/spell/light
# https://www.dnd-spells.com/spell/lightning-arrow
# https://www.dnd-spells.com/spell/lightning-bolt
# https://www.dnd-spells.com/spell/locate-animals-or-plants-ritual
# https://www.dnd-spells.com/spell/locate-creature
# https://www.dnd-spells.com/spell/locate-object
# https://www.dnd-spells.com/spell/longstrider
# https://www.dnd-spells.com/spell/mage-armor
# https://www.dnd-spells.com/spell/mage-hand
# https://www.dnd-spells.com/spell/magic-circle
# https://www.dnd-spells.com/spell/magic-jar
# https://www.dnd-spells.com/spell/magic-missile
# https://www.dnd-spells.com/spell/magic-mouth-ritual
# https://www.dnd-spells.com/spell/magic-weapon
# https://www.dnd-spells.com/spell/major-image
# https://www.dnd-spells.com/spell/mass-cure-wounds
# https://www.dnd-spells.com/spell/mass-heal
# https://www.dnd-spells.com/spell/mass-healing-word
# https://www.dnd-spells.com/spell/mass-suggestion
# https://www.dnd-spells.com/spell/maze
# https://www.dnd-spells.com/spell/meld-into-stone-ritual
# https://www.dnd-spells.com/spell/melfs-acid-arrow
# https://www.dnd-spells.com/spell/mending
# https://www.dnd-spells.com/spell/message
# https://www.dnd-spells.com/spell/meteor-swarm
# https://www.dnd-spells.com/spell/mind-blank
# https://www.dnd-spells.com/spell/minor-illusion
# https://www.dnd-spells.com/spell/mirage-arcane
# https://www.dnd-spells.com/spell/mirror-image
# https://www.dnd-spells.com/spell/mislead
# https://www.dnd-spells.com/spell/misty-step
# https://www.dnd-spells.com/spell/modify-memory
# https://www.dnd-spells.com/spell/moonbeam
# https://www.dnd-spells.com/spell/mordenkainens-faithful-hound
# https://www.dnd-spells.com/spell/mordenkainens-magnificent-mansion
# https://www.dnd-spells.com/spell/mordenkainens-private-sanctum
# https://www.dnd-spells.com/spell/mordenkainens-sword
# https://www.dnd-spells.com/spell/move-earth
# https://www.dnd-spells.com/spell/nondetection
# https://www.dnd-spells.com/spell/nystuls-magic-aura
# https://www.dnd-spells.com/spell/otilukes-freezing-sphere
# https://www.dnd-spells.com/spell/otilukes-resilient-sphere
# https://www.dnd-spells.com/spell/ottos-irresistible-dance
# https://www.dnd-spells.com/spell/pass-without-trace
# https://www.dnd-spells.com/spell/passwall
# https://www.dnd-spells.com/spell/phantasmal-force
# https://www.dnd-spells.com/spell/phantasmal-killer
# https://www.dnd-spells.com/spell/phantom-steed-ritual
# https://www.dnd-spells.com/spell/planar-ally
# https://www.dnd-spells.com/spell/planar-binding
# https://www.dnd-spells.com/spell/plane-shift
# https://www.dnd-spells.com/spell/plant-growth
# https://www.dnd-spells.com/spell/poison-spray
# https://www.dnd-spells.com/spell/polymorph
# https://www.dnd-spells.com/spell/power-word-kill
# https://www.dnd-spells.com/spell/power-word-stun
# https://www.dnd-spells.com/spell/prayer-of-healing
# https://www.dnd-spells.com/spell/prestidigitation
# https://www.dnd-spells.com/spell/prismatic-spray
# https://www.dnd-spells.com/spell/prismatic-wall
# https://www.dnd-spells.com/spell/produce-flame
# https://www.dnd-spells.com/spell/programmed-illusion
# https://www.dnd-spells.com/spell/project-image
# https://www.dnd-spells.com/spell/protection-from-energy
# https://www.dnd-spells.com/spell/protection-from-evil-and-good
# https://www.dnd-spells.com/spell/protection-from-poison
# https://www.dnd-spells.com/spell/purify-food-and-drink-ritual
# https://www.dnd-spells.com/spell/raise-dead
# https://www.dnd-spells.com/spell/rarys-telepathic-bond-ritual
# https://www.dnd-spells.com/spell/ray-of-enfeeblement
# https://www.dnd-spells.com/spell/ray-of-frost
# https://www.dnd-spells.com/spell/ray-of-sickness
# https://www.dnd-spells.com/spell/regenerate
# https://www.dnd-spells.com/spell/reincarnate
# https://www.dnd-spells.com/spell/remove-curse
# https://www.dnd-spells.com/spell/resistance
# https://www.dnd-spells.com/spell/resurrection
# https://www.dnd-spells.com/spell/reverse-gravity
# https://www.dnd-spells.com/spell/revivify
# https://www.dnd-spells.com/spell/rope-trick
# https://www.dnd-spells.com/spell/sacred-flame
# https://www.dnd-spells.com/spell/sanctuary
# https://www.dnd-spells.com/spell/scorching-ray
# https://www.dnd-spells.com/spell/scrying
# https://www.dnd-spells.com/spell/searing-smite
# https://www.dnd-spells.com/spell/see-invisibility
# https://www.dnd-spells.com/spell/seeming
# https://www.dnd-spells.com/spell/sending
# https://www.dnd-spells.com/spell/sequester
# https://www.dnd-spells.com/spell/shapechange
# https://www.dnd-spells.com/spell/shatter
# https://www.dnd-spells.com/spell/shield
# https://www.dnd-spells.com/spell/shield-of-faith
# https://www.dnd-spells.com/spell/shillelagh
# https://www.dnd-spells.com/spell/shocking-grasp
# https://www.dnd-spells.com/spell/silence-ritual
# https://www.dnd-spells.com/spell/silent-image
# https://www.dnd-spells.com/spell/simulacrum
# https://www.dnd-spells.com/spell/sleep
# https://www.dnd-spells.com/spell/sleet-storm
# https://www.dnd-spells.com/spell/slow
# https://www.dnd-spells.com/spell/spare-the-dying
# https://www.dnd-spells.com/spell/speak-with-animals-ritual
# https://www.dnd-spells.com/spell/speak-with-dead
# https://www.dnd-spells.com/spell/speak-with-plants
# https://www.dnd-spells.com/spell/spider-climb
# https://www.dnd-spells.com/spell/spike-growth
# https://www.dnd-spells.com/spell/spirit-guardians
# https://www.dnd-spells.com/spell/spiritual-weapon
# https://www.dnd-spells.com/spell/staggering-smite
# https://www.dnd-spells.com/spell/stinking-cloud
# https://www.dnd-spells.com/spell/stone-shape
# https://www.dnd-spells.com/spell/stoneskin
# https://www.dnd-spells.com/spell/storm-of-vengeance
# https://www.dnd-spells.com/spell/suggestion
# https://www.dnd-spells.com/spell/sunbeam
# https://www.dnd-spells.com/spell/sunburst
# https://www.dnd-spells.com/spell/swift-quiver
# https://www.dnd-spells.com/spell/symbol
# https://www.dnd-spells.com/spell/tashas-hideous-laughter
# https://www.dnd-spells.com/spell/telekinesis
# https://www.dnd-spells.com/spell/telepathy
# https://www.dnd-spells.com/spell/teleport
# https://www.dnd-spells.com/spell/teleportation-circle
# https://www.dnd-spells.com/spell/tensers-floating-disk-ritual
# https://www.dnd-spells.com/spell/thaumaturgy
# https://www.dnd-spells.com/spell/thorn-whip
# https://www.dnd-spells.com/spell/thunderous-smite
# https://www.dnd-spells.com/spell/thunderwave
# https://www.dnd-spells.com/spell/time-stop
# https://www.dnd-spells.com/spell/tongues
# https://www.dnd-spells.com/spell/transport-via-plants
# https://www.dnd-spells.com/spell/tree-stride
# https://www.dnd-spells.com/spell/true-polymorph
# https://www.dnd-spells.com/spell/true-resurrection
# https://www.dnd-spells.com/spell/true-seeing
# https://www.dnd-spells.com/spell/true-strike
# https://www.dnd-spells.com/spell/tsunami
# https://www.dnd-spells.com/spell/unseen-servant-ritual
# https://www.dnd-spells.com/spell/vampiric-touch
# https://www.dnd-spells.com/spell/wall-of-fire
# https://www.dnd-spells.com/spell/wall-of-force
# https://www.dnd-spells.com/spell/wall-of-ice
# https://www.dnd-spells.com/spell/wall-of-stone
# https://www.dnd-spells.com/spell/wall-of-thorns
# https://www.dnd-spells.com/spell/warding-bond
# https://www.dnd-spells.com/spell/water-breathing-ritual
# https://www.dnd-spells.com/spell/water-walk-ritual
# https://www.dnd-spells.com/spell/web
# https://www.dnd-spells.com/spell/weird
# https://www.dnd-spells.com/spell/wind-walk
# https://www.dnd-spells.com/spell/wind-wall
# https://www.dnd-spells.com/spell/wish
# https://www.dnd-spells.com/spell/witch-bolt
# https://www.dnd-spells.com/spell/word-of-recall
# https://www.dnd-spells.com/spell/wrathful-smite
# https://www.dnd-spells.com/spell/zone-of-truth
# https://www.dnd-spells.com/spell/power-word-heal
# https://www.dnd-spells.com/spell/vicious-mockery
# https://www.dnd-spells.com/spell/trap-the-soul
# error
# https://www.dnd-spells.com/spell/thunderclap
# https://www.dnd-spells.com/spell/earth-tremor
# https://www.dnd-spells.com/spell/pyrotechnics
# https://www.dnd-spells.com/spell/skywrite-ritual
# https://www.dnd-spells.com/spell/warding-wind
# https://www.dnd-spells.com/spell/create-bonfire
# https://www.dnd-spells.com/spell/control-flames
# https://www.dnd-spells.com/spell/frostbite
# https://www.dnd-spells.com/spell/gust
# https://www.dnd-spells.com/spell/magic-stone
# https://www.dnd-spells.com/spell/mold-earth
# https://www.dnd-spells.com/spell/shape-water
# https://www.dnd-spells.com/spell/absorb-elements
# https://www.dnd-spells.com/spell/beast-bond
# https://www.dnd-spells.com/spell/ice-knife
# https://www.dnd-spells.com/spell/dust-devil
# https://www.dnd-spells.com/spell/earthbind
# https://www.dnd-spells.com/spell/erupting-earth
# https://www.dnd-spells.com/spell/flame-arrows
# https://www.dnd-spells.com/spell/tidal-wave
# https://www.dnd-spells.com/spell/wall-of-water
# https://www.dnd-spells.com/spell/elemental-bane
# https://www.dnd-spells.com/spell/watery-sphere
# https://www.dnd-spells.com/spell/control-winds
# https://www.dnd-spells.com/spell/maelstrom
# https://www.dnd-spells.com/spell/transmute-rock
# https://www.dnd-spells.com/spell/bones-of-the-earth
# https://www.dnd-spells.com/spell/investiture-of-flame
# https://www.dnd-spells.com/spell/investiture-of-ice
# https://www.dnd-spells.com/spell/investiture-of-stone
# https://www.dnd-spells.com/spell/investiture-of-wind
# https://www.dnd-spells.com/spell/primordial-ward
# https://www.dnd-spells.com/spell/whirlwind
# https://www.dnd-spells.com/spell/catapult
# https://www.dnd-spells.com/spell/aganazzars-scorcher
# https://www.dnd-spells.com/spell/maximilians-earthen-grasp
# https://www.dnd-spells.com/spell/snillocs-snowball-swarm
# https://www.dnd-spells.com/spell/melfs-minute-meteors
# https://www.dnd-spells.com/spell/storm-sphere
# https://www.dnd-spells.com/spell/vitriolic-sphere
# https://www.dnd-spells.com/spell/immolation
# https://www.dnd-spells.com/spell/abi-dalzims-horrid-wilting
# https://www.dnd-spells.com/spell/wall-of-sand
# https://www.dnd-spells.com/spell/booming-blade
# https://www.dnd-spells.com/spell/green-flame-blade
# https://www.dnd-spells.com/spell/lightning-lure
# https://www.dnd-spells.com/spell/sword-burst
