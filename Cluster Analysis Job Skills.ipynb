# %%
import numpy as np
import pandas as pd
import seaborn as sns
import urllib2
import requests

import bs4
from bs4 import BeautifulSoup
import json
import csv
import time
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # scraping jobs 100 miles radius of Dayton
# Sinclair students like to stay close to home or move someplace like Texas. Within a 100 mile radius is Cincinnati, Columbus and Indianapolis
# Majors = user support, software development, web development, network manager, network engineer, cyber security
# Searched for all salaries

# %% [markdown]
# Setting up lists to hold scraped data. Only need certain data
# searchCriteria is the degree
# jobTitle
# companyName
# cityLocation
# description
#
# source is where the listing was obtained.  For example, Indeed.com, USA Jobs, manual input (Sinclair data)

# %%
pd.set_option('max_colwidth',500)    # to remove column limit (Otherwise, we'll lose some info)
df = pd.DataFrame()   # create a new data frame

searchCriteria=[]
jobTitle = []
companyName=[]
cityLocation=[]
description=[]
source=[]
SCCdegree=[]

# %%
#I backed up data after each stage because I am paranoid
BackupsearchCriteria=[]
BackupjobTitle = []
BackupcompanyName=[]
BackupcityLocation=[]
Backupdescription=[]
BackupSCCDegree=[]
BackupDescription=[]

# %%
#list of Sinclair degrees
degrees=['user+support', 'software+development', 'web+development', 
         'network+manager', 'network+engineer', 'cyber+security']

# %%
    
for degree in degrees:
    base_url = 'http://www.indeed.com/jobs?q='+degree+'&l=dayton+oh&radius=100'
#   http://www.indeed.com/jobs?q=user+support&l=dayton+oh&radius=100&start=10&pp=#
    soup = BeautifulSoup(urllib2.urlopen(base_url).read())
    gData = soup.find_all("div",{"class":"row result"})

    time.sleep(1)
    for item in gData:
            searchCriteria.append(degree)
            jobTitle.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
            companyName.append((item.find_all("span",{"class":"company"})[0].text).lstrip().replace('\n',''))
            cityLocation.append(item.find_all("span",{"class":"location"})[0].text)
            description.append(item.find_all("span",{"class":"summary"})[0].text)
            source.append('Indeed')
            SCCdegree.append(degree)
    
    gData = soup.find_all("div",{"class":" row result"})
    for item in gData:
            searchCriteria.append(degree)
            jobTitle.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
            companyName.append((item.find_all("span",{"class":"company"})[0].text).lstrip().replace('\n',''))
            cityLocation.append(item.find_all("span",{"class":"location"})[0].text)
            description.append(item.find_all("span",{"class":"summary"})[0].text)
            source.append('Indeed')
            SCCdegree.append(degree)

# %%
print len(searchCriteria)
print len(jobTitle)
print len(companyName)
print len(cityLocation)
print len(description)
print len(source)
print len(SCCdegree)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
#backing up so if the lengths are different I haven't lost everything
BackupsearchCriteria =searchCriteria 
BackupjobTitle =jobTitle
BackupcompanyName=companyName
BackupcityLocation=cityLocation
Backupdescription=description
BackupSCCDegree=SCCdegree
BackupSource=source

# %%
# to pull pages after the first page

degrees=['user+support', 'software+development', 'web+development', 
         'network+manager']
# degrees=['user+support', 'software+development', 'web+development', 
#          'network+manager', 'network+engineer', 'cyber+security']
    
for degree in degrees:
    pVariableNu=10
    totalPages=180
    #pagesPerDegree=[208, 400, 180, 179, 70, 50]
    
#     if degree == 'user+support':
#         totalPages=208
#     elif degree == 'software+development':
#         totalPages=149
#     elif degree == 'web+development':
#         totalPages=179
#     elif degree ==  'network+manager':
#         totalPages=179
#     elif degree ==  'network+engineer':
#         totalPages=73
#     elif degree ==  'cyber+security':
#         totalPages=53   
   
       
    
    for pages in range(130,totalPages):
        time.sleep(1) 
        pVariableNu=10*pages
        pVariable=str(pVariableNu)
        time.sleep(1)
    
        base_url = 'http://www.indeed.com/jobs?q='+degree+'&l=dayton+oh&radius=100&start='+pVariable
        soup = BeautifulSoup(urllib2.urlopen(base_url).read())
        gData = soup.find_all("div",{"class":"row result"})
        print pages
        
        for item in gData:
            searchCriteria.append(degree)
            jobTitle.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
            companyName.append((item.find_all("span",{"class":"company"})[0].text).lstrip().replace('\n',''))
            cityLocation.append(item.find_all("span",{"class":"location"})[0].text)
            description.append(item.find_all("span",{"class":"summary"})[0].text)
            source.append('Indeed')
            SCCdegree.append(degree)
            print degree
            if len(searchCriteria) != len(jobTitle):
                jobTitle.append('')
            if len(searchCriteria) != len(companyName):
                jobTitle.append('')
            if len(searchCriteria) != len(cityLocation):
                jobTitle.append('')
            if len(searchCriteria) != len(description):
                jobTitle.append('')
            if len(searchCriteria) != len(source):
                jobTitle.append('')  
            if len(searchCriteria) != len(SCCdegree):
                jobTitle.append('')
        gData = soup.find_all("div",{"class":" row result"})
        for item in gData:
            searchCriteria.append(degree)
            jobTitle.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
            companyName.append((item.find_all("span",{"class":"company"})[0].text).lstrip().replace('\n',''))
            cityLocation.append(item.find_all("span",{"class":"location"})[0].text)
            description.append(item.find_all("span",{"class":"summary"})[0].text)
            source.append('Indeed')
            SCCdegree.append(degree)
            if len(searchCriteria) != len(jobTitle):
                jobTitle.append('')
            if len(searchCriteria) != len(companyName):
                jobTitle.append('')
            if len(searchCriteria) != len(cityLocation):
                jobTitle.append('')
            if len(searchCriteria) != len(description):
                jobTitle.append('')
            if len(searchCriteria) != len(source):
                jobTitle.append('')  
            if len(searchCriteria) != len(SCCdegree):
                jobTitle.append('')
            print degree
# Out:
# 130
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 131
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 132
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 133
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 134
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 135
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 136
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 137
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 138
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 139
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 140
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 141
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 142
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 143
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 144
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 145
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 146
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 147
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 148
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 149
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 150
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 151
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 152
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 153
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 154
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 155
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 156
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 157
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 158
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 159
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 160
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 161
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 162
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 163
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 164
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 165
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 166
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 167
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 168
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 169
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 170
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 171
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 172
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 173
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 174
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 175
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 176
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 177
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 178
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 179
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# user+support
# 130
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 131
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 132
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 133
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 134
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 135
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 136
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 137
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 138
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 139
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 140
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 141
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 142
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 143
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 144
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 145
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 146
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 147
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 148
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 149
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 150
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 151
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 152
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 153
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 154
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 155
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 156
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 157
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 158
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 159
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 160
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 161
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 162
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 163
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 164
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 165
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 166
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 167
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 168
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 169
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 170
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 171
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 172
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 173
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 174
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 175
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 176
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 177
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 178
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 179
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# software+development
# 130
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 131
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 132
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 133
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 134
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 135
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 136
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 137
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 138
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 139
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 140
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 141
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 142
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 143
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 144
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 145
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 146
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 147
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 148
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 149
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 150
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 151
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 152
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 153
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 154
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 155
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 156
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 157
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 158
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 159
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 160
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 161
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 162
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 163
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 164
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 165
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# 166
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# web+development
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-11-58a26ad23c4c> in <module>()
#      33
#      34         base_url = 'http://www.indeed.com/jobs?q='+degree+'&l=dayton+oh&radius=100&start='+pVariable
# ---> 35         soup = BeautifulSoup(urllib2.urlopen(base_url).read())
#      36         gData = soup.find_all("div",{"class":"row result"})
#      37         print pages
#
# //anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# //anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# //anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# //anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# //anaconda/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# //anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1196         except socket.error, err: # XXX what error?
#    1197             h.close()
# -> 1198             raise URLError(err)
#    1199         else:
#    1200             try:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
print len(searchCriteria)
print len(jobTitle)
print len(companyName)
print len(cityLocation)
print len(description)
print len(source)
print len(SCCdegree)
# Out:
# 1080
# 1080
# 1080
# 1080
# 1080
# 1080
# 1080

# %%
#only use this if the index is off

# searchCriteria = BackupsearchCriteria
# jobTitle =BackupjobTitle
# companyName=BackupcompanyName
# cityLocation=BackupcityLocation
# description =Backupdescription
# SCCdegree=BackupSCCDegree
# source=BackupSource

# %%
print len(BackupsearchCriteria)
print len(BackupjobTitle)
print len(BackupcompanyName)
print len(BackupcityLocation)
print len(Backupdescription)
print len(BackupSource)
print len(BackupSCCDegree)

# %%
TBackupsearchCriteria=[]
TBackupjobTitle = []
TBackupcompanyName=[]
TBackupcityLocation=[]
TBackupdescription=[]
TBackupSCCDegree=[]
TBackupDescription=[]

# %%
TBackupsearchCriteria =searchCriteria 
TBackupjobTitle =jobTitle
TBackupcompanyName=companyName
TBackupcityLocation=cityLocation
TBackupdescription=description
TBackupSCCDegree=SCCdegree
TBackupSource=source

# %%
len(TBackupdescription)

# %%
dictPostingsTEMP={'Search Criteria':searchCriteria,
              'Job Title':jobTitle,
              'Company Name':companyName,
              'City Location':cityLocation,
              'Description':description,
              'Source':source,
              'Degree': SCCdegree}

searchListingsTEMP = pd.DataFrame(dictPostingsTEMP)
print searchListingsTEMP.shape
searchListingsTEMP=searchListingsTEMP.drop_duplicates(take_last=True)
print searchListingsTEMP.shape
# Out:
# (1080, 7)
# (56, 7)
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead

# %%
searchListingsTEMP.to_csv("Part2Listings1.csv", encoding ='utf-8')

# %%
searchListingsTEMP.tail(10)
# Out:
#              City Location                     Company Name           Degree  \
# 953           Columbus, OH                       Huntington  network+manager
# 1071       Xenia, OH 45385         Kettering Health Network  network+manager
# 1072            London, OH  Advanced Drainage Systems (ADS)  network+manager
# 1073      Muncie, IN 47304           Fresenius Medical Care  network+manager
# 1074  Miamisburg, OH 45342        O'Neil & Associates, Inc.  network+manager
# 1075        Cincinnati, OH                     Mercy Health  network+manager
# 1076            Dayton, OH                        Tektronix  network+manager
# 1077        Cincinnati, OH                               EY  network+manager
# 1078         Covington, KY                   Pro Mach, Inc.  network+manager
# 1079            Dayton, OH         Kettering Health Network  network+manager
#
#                                                                                                                                                                 Description  \
# 953    \nCompliance Group Manager - Deposit Products & Business Banking Support. Huntington Bancshares Incorporated is an approximately $100 billion asset regional bank...
# 1071      \nFunction as primary care manager for panel of patients. Nurse Practitioner (NP) will provide primary care with the cognizance or supervision of a physician....
# 1072  \nLoaders report directly to the Yard Supervisor and/or Yard Manager. ADS operates a global network of 61 manufacturing plants and 29 distribution centers through...
# 1073                                                  \nRoutinely meets with the Clinical Manager to discuss personnel and patient care status, issues, and information....
# 1074           \nSoftware/hardware skills and network familiarity. Works closely with Program/Project Manager and. Works at the direction of Program/Project Manager or....
# 1075   \nSupports provider data requests for the clinically integrated network. Serves as liaison between CVO, Mercy Health Select Network Operations and Data Analytics...
# 1076                             \nUse project deliverables to develop the work breakdown structure and network diagram that then drive the detailed activity/task list....
# 1077                     \nRisk Assurance Manager. Risk Assurance Manager (Multiple Positions). Maintain long-term client relationships and networks. Ernst & Young U.S....
# 1078     \nCorporate Audit Manager - Job Description:. Strong interpersonal skills are required, enabling individual to network and develop relationships throughout the...
# 1079     \nReports directly to the Administrative Director of PM&R with indirect supervision from the Senior Physical Therapist, Program Manager and Medical Director of...
#
#                                                             Job Title  \
# 953   Compliance Group Manager - Deposit Products & Business Banki...
# 1071                             NURSE PRACTITIONER - FAMILY PRACTICE
# 1072                                          Yard Loader - 2nd Shift
# 1073                                         RN-FMS Travel Nurse only
# 1074                                              Technical Writer II
# 1075  Data Systems Specialist CVO (Certified Verification Organiza...
# 1076                                                        Assembler
# 1077                      Risk Assurance Manager (Multiple Positions)
# 1078                                          Corporate Audit Manager
# 1079                                               PHYSICAL THERAPIST
#
#       Search Criteria  Source
# 953   network+manager  Indeed
# 1071  network+manager  Indeed
# 1072  network+manager  Indeed
# 1073  network+manager  Indeed
# 1074  network+manager  Indeed
# 1075  network+manager  Indeed
# 1076  network+manager  Indeed
# 1077  network+manager  Indeed
# 1078  network+manager  Indeed
# 1079  network+manager  Indeed

# %%
searchListingsTEMP['Search Criteria'].value_counts()

# %%
dfDescription = pd.DataFrame(description)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
v = CountVectorizer(
    binary=True,  # Create binary features
    stop_words='english', # Ignore common words such as 'the', 'and'
    max_features=200, # Only use the top 50 most common words
)

# %%
wordsDescription = v.fit_transform(dfDescription[0]).todense()     #no difference between data.title and data['title]
wordsDescription = pd.DataFrame(wordsDescription, columns=v.get_feature_names())

# %%
print wordsDescription.sum().sort_values(ascending=False)

# %%
urlCB='http://www.careerbuilder.com/jobs-data-engineer-in-chicago,il?keywords=Data+Engineer&location=Chicago%2C+IL'

# %%
soupCB = BeautifulSoup(urllib2.urlopen(urlCB).read())
    
            
gDataCB = soupCB.find_all("div",{"class":"row"})

# %%
gDataCB

# %%
print soupCB.prettify()
